# %% [markdown]
# <a href="https://colab.research.google.com/github/JGCMachado/Scripts/blob/main/MVP3_SQLs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **SQLs utilizados para conferir os resultados gerados no dashboard do Quicksight**

# %% [markdown]
# **1) Quais políticos conseguiram aprovar mais emendas orçamentárias?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **2) Quais políticos aprovaram maiores valores?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **3) Para quais setores foram destinadas mais verbas?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **4) Quais estados receberam mais verbas?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
